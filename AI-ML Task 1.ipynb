# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
file=pd.read_csv(r'C:\Users\Priyansh\Downloads\IEA-EV-dataEV salesHistoricalCars.csv')

# %%
#1 Understanding the Data

# %%
file.head()
# Out:
#       region    category       parameter  mode powertrain  year      unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011  Vehicles
# 1  Australia  Historical  EV stock share  Cars         EV  2011   percent
# 2  Australia  Historical  EV sales share  Cars         EV  2011   percent
# 3  Australia  Historical        EV stock  Cars        BEV  2011  Vehicles
# 4  Australia  Historical        EV stock  Cars        BEV  2012  Vehicles
#
#        value
# 0   49.00000
# 1    0.00039
# 2    0.00650
# 3   49.00000
# 4  220.00000

# %%
file.tail()
# Out:
#      region    category           parameter  mode powertrain  year      unit  \
# 3793  World  Historical            EV stock  Cars        BEV  2023  Vehicles
# 3794  World  Historical            EV sales  Cars        BEV  2023  Vehicles
# 3795  World  Historical      EV sales share  Cars         EV  2023   percent
# 3796  World  Historical      EV stock share  Cars         EV  2023   percent
# 3797  World  Historical  Electricity demand  Cars         EV  2023       GWh
#
#            value
# 3793  28000000.0
# 3794   9500000.0
# 3795        18.0
# 3796         3.2
# 3797     97000.0

# %%
file.shape
# Out:
# (3798, 8)

# %%
file.describe
# Out:
# <bound method NDFrame.describe of          region    category           parameter  mode powertrain  year  \
# 0     Australia  Historical            EV sales  Cars        BEV  2011
# 1     Australia  Historical      EV stock share  Cars         EV  2011
# 2     Australia  Historical      EV sales share  Cars         EV  2011
# 3     Australia  Historical            EV stock  Cars        BEV  2011
# 4     Australia  Historical            EV stock  Cars        BEV  2012
# ...         ...         ...                 ...   ...        ...   ...
# 3793      World  Historical            EV stock  Cars        BEV  2023
# 3794      World  Historical            EV sales  Cars        BEV  2023
# 3795      World  Historical      EV sales share  Cars         EV  2023
# 3796      World  Historical      EV stock share  Cars         EV  2023
# 3797      World  Historical  Electricity demand  Cars         EV  2023
#
#           unit         value
# 0     Vehicles  4.900000e+01
# ...

# %%
file.describe()
# Out:
#               year         value
# count  3798.000000  3.798000e+03
# mean   2017.369932  1.009542e+05
# std       3.809226  8.184402e+05
# min    2010.000000  1.500000e-05
# 25%    2014.000000  2.300000e+00
# 50%    2018.000000  1.900000e+02
# 75%    2021.000000  6.800000e+03
# max    2023.000000  2.800000e+07

# %%
file.columns
# Out:
# Index(['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit',
#        'value'],
#       dtype='object')

# %%
file.nunique()
# Out:
# region         52
# category        1
# parameter       7
# mode            1
# powertrain      4
# year           14
# unit            5
# value         814
# dtype: int64

# %%
file['powertrain'].unique()
# Out:
# array(['BEV', 'EV', 'PHEV', 'FCEV'], dtype=object)

# %%
file['unit'].unique()
# Out:
# array(['Vehicles', 'percent', 'GWh', 'Milion barrels per day',
#        'Oil displacement, million lge'], dtype=object)

# %%
#2 Cleaning the Data

# %%
file.isnull().sum()
# Out:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64

# %%
data=file.drop(["category","mode"],axis=1)

# %%
#3 Relationship Analysis

# %%
data['value']=data['value'].astype(int)

# %%
sns.lineplot(x="year",y="value",data=data)
# Out:
# <Axes: xlabel='year', ylabel='value'>

# %%
#Conclusion- With time the value of car is increasing

# %%
sns.scatterplot(y="value",x="year",data=data,hue='powertrain')
# Out:
# <Axes: xlabel='year', ylabel='value'>

# %%
#Conclusion- With time the value and usage of BEV powertrain is increaing

# %%
sns.barplot(x="unit",y="region",data=data,hue='parameter')
# Out:
# <Axes: xlabel='unit', ylabel='region'>

# %%
#Conclusion-GWh with Electicity Demand parameter,Milion barrels per day with Oil displacement Mbd parameter and million Ige with Oil displacement,million Ige are widely used units across various regions

# %%
plt.pie(data['value'],labels=data['powertrain'])
plt.show()

# %%
#Conclusion- BEV powertrain has highest value among all powertrains

# %%
sns.pairplot(data)

# %%
#Conclusion- Gives correlation between each corelated variables
